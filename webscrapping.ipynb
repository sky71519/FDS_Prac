# %% [markdown]
# <a href="https://colab.research.google.com/github/sky71519/FDS_Prac/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
page = requests.get("https://www.rjcollege.edu.in/about-us/")
soup = BeautifulSoup(page.content,'html.parser')
str3 = soup.find_all('p')[0].get_text()
sents = sent_tokenize (str3)
words = word_tokenize (str3)
print(words)
# Out:
# ['On', 'the', 'auspicious', 'day', 'of', 'Shri', 'Krishna', 'Janmashtami', ',', '15th', 'August', '1938', ',', 'the', 'people', 'of', 'Ghatkopar', 'and', 'the', 'surrounding', 'suburbs', 'witnessed', 'the', 'birth', 'of', 'Hindi', 'Vidya', 'Prachar', 'Samiti', ',', 'a', 'brain', 'child', 'of', 'a', 'visionary', 'Late', 'Shri', 'Nandkishore', 'Singh', 'Jairamji', '.', 'The', 'Samiti', 'was', 'established', 'with', 'the', 'objectives', 'of', 'catering', 'to', 'the', 'educational', 'needs', 'of', 'the', 'Hindi', 'speaking', 'community', '.', 'It', 'made', 'a', 'humble', 'beginning', 'by', 'starting', 'a', 'primary', 'school', ',', 'which', 'gradually', 'expanded', 'into', 'a', 'full-fledged', 'secondary', 'school', '.', 'The', 'Hindi', 'High', 'School', 'with', 'its', 'high', 'academic', 'standards', 'has', 'carved', 'for', 'itself', 'a', 'place', 'not', 'only', 'among', 'leading', 'secondary', 'schools', 'in', 'Mumbai', 'but', 'also', 'educational', 'institutions', 'imparting', 'instru
# ...

# %%
print(soup.title)
# Out:
# <title>ABOUT US – R J COLLEGE</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.parent.name)
# Out:
# head

# %%
page = requests.get("https://www.rjcollege.edu.in/pgadmission2022-23/")
soup = BeautifulSoup(page.content,'html.parser')
table1 = soup.find('table', id='tablepress-56')
print(table1)
# Out:
# <table class="tablepress tablepress-id-56" id="tablepress-56">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1">Course</th><th class="column-2">Eligibility</th><th class="column-3">Last date of Online form Filling</th><th class="column-4">Display of Provisional List</th><th class="column-5">Counseling and allotment of Seats on the basis of Merit</th><th class="column-6">Admission Criteria</th>
# </tr>
# </thead>
# <tbody class="row-hover">
# <tr class="row-2 even">
# <td class="column-1">M.Sc Chemistry (Physical, Organic &amp; Inorganic)</td><td class="column-2">B.Sc Chemistry</td><td class="column-3">30 June 2022 at 6.00 PM</td><td class="column-4">1July 2022 at 6.00 PM</td><td class="column-5">Will be announced soon</td><td class="column-6">on the Basis of Merit Counselling will be done and seats will be allotted)</td>
# </tr>
# <tr class="row-3 odd">
# ...

# %%
import nltk
import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.rjcollege.edu.in/pgadmission2022-23/")
soup = BeautifulSoup(r.content,'html.parser')
image_list = []
images = soup.select('img')
for image in images:
  src = image.get('src')
  alt = image.get('alt')
  image_list.append({"src": src, "alt":alt})
  print(image)
# Out:
# <img alt="R J COLLEGE" class="custom-logo lazyload" data-sizes="auto" data-src="https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1.png" data-srcset="https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1.png 356w, https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1-150x42.png 150w, https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1-285x79.png 285w" decoding="async" height="99" src="..." width="356"/>
# <img alt="R J COLLEGE" class="custom-logo" data-eio="l" height="99" sizes="(max-width: 356px) 100vw, 356px" src="https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1.png" srcset="https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1.png 356w, https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1-150x42.png 150w, https://www.rjcollege.edu.in/wp-content/uploads/2021/12/website-logo-1-285x79.png 285w" width="356"/>
# ...

# %%
page = requests.get("https://www.w3schools.com/xml/note.xml")
soup = BeautifulSoup("<note>",'xml')
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <note/>

# %%
detail = requests.get('https://maps2.dcgis.dc.gov/dcgis/rest/services/FEEDS/MPD/MapServer/2/query?where=1%3D1&outFields=*&outSR=4326&f=json')
print(detail.status_code) 
data_json = detail.json()
print(type(data_json))
for x in data_json:
    print(x)
print("\n")
print(data_json["features"])
# Out:
# 200
# <class 'dict'>
# displayFieldName
# fieldAliases
# geometryType
# spatialReference
# fields
# features
# exceededTransferLimit
#
#
# ...
